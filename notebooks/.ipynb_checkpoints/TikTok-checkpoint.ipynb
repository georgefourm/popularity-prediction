# %%
import pandas as pd
# %cd ..
# Out:
# C:\Users\georg\Documents\msc-projcet

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_validate
from sklearn import svm,tree,naive_bayes,linear_model
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
df = pd.read_csv("data/interim/tracks.csv")

# %%
df.head()
# Out:
#                        id             title          album     views  videos  \
# 0  1sx0XsWUusUoPstbvokZjP             A-O-K          A-O-K  24500000      21
# 1  6n4U3TlzUGhdSFbUUhTvLP   Walk It Talk It     Culture II     15000       2
# 2  4jDmJ51x1o9NZB5Nxxc7gY  Careless Whisper   Heart & Soul  12000000       4
# 3  2P5yIMu2DNeMXTyOANKS6k            Nobody  Be the Cowboy    245100       1
# 4  1Wdj4wRDYS7aT4CoPS0mAH    You Are Enough       Atlas: I   7900000      15
#
#                  tt_id  danceability  energy  key  loudness  ...  \
# 0  6953851540646709249         0.731   0.626   11    -6.919  ...
# 1  6790838366146398209         0.907   0.633    2    -5.145  ...
# 2  6712428451149645825         0.574   0.629    2    -8.815  ...
# 3  6754663153281321734         0.398   0.717    0    -5.253  ...
# 4  6779450671369291777         0.593   0.500    1    -8.532  ...
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1830    0.862   82.488  audio_features
# 1          0.000003    0.1060    0.395  145.914  audio_features
# 2          0.000000    0.2710    0.786  153.119  audio_features
# 3          0.000000    0.0850    0.487  117.296  audio_features
# 4          0.000012    0.0837    0.465  117.996  audio_features
#
#                                     uri  \
# 0  spotify:track:1sx0XsWUusUoPstbvokZjP
# 1  spotify:track:6n4U3TlzUGhdSFbUUhTvLP
# 2  spotify:track:4jDmJ51x1o9NZB5Nxxc7gY
# 3  spotify:track:2P5yIMu2DNeMXTyOANKS6k
# 4  spotify:track:1Wdj4wRDYS7aT4CoPS0mAH
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1sx0XsWUusUo...
# 1  https://api.spotify.com/v1/tracks/6n4U3TlzUGhd...
# 2  https://api.spotify.com/v1/tracks/4jDmJ51x1o9N...
# 3  https://api.spotify.com/v1/tracks/2P5yIMu2DNeM...
# 4  https://api.spotify.com/v1/tracks/1Wdj4wRDYS7a...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1sx0...      173640
# 1  https://api.spotify.com/v1/audio-analysis/6n4U...      276147
# 2  https://api.spotify.com/v1/audio-analysis/4jDm...      300107
# 3  https://api.spotify.com/v1/audio-analysis/2P5y...      193429
# 4  https://api.spotify.com/v1/audio-analysis/1Wdj...      180087
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#               views       videos         tt_id  danceability       energy  \
# count  2.187000e+03  2187.000000  2.187000e+03   2187.000000  2187.000000
# mean   6.696997e+06     5.841792  6.381853e+18      0.643339     0.615903
# std    1.785776e+07    14.513099  1.585278e+18      0.180653     0.227732
# min    0.000000e+00     1.000000  6.557410e+05      0.000000     0.000000
# 25%    5.785000e+04     1.000000  6.726731e+18      0.542000     0.465000
# 50%    1.597000e+05     3.000000  6.808590e+18      0.674000     0.653000
# 75%    2.700000e+06     5.000000  6.929740e+18      0.774000     0.794000
# max    2.057000e+08   289.000000  7.013915e+18      0.979000     1.000000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2187.000000  2187.000000  2187.000000  2187.000000   2187.000000
# mean      5.303612    -8.172599     0.556927     0.111113      0.299595
# std       3.608240     4.881110     0.496862     0.117416      0.308458
# min       0.000000   -60.000000     0.000000     0.000000      0.000000
# 25%       2.000000    -9.633500     0.000000     0.039200      0.039250
# 50%       5.000000    -6.948000     1.000000     0.059300      0.181000
# 75%       8.000000    -5.188000     1.000000     0.132500      0.501500
# max      11.000000    -0.949000     1.000000     0.935000      0.996000
#
#        instrumentalness     liveness      valence        tempo    duration_ms  \
# count       2187.000000  2187.000000  2187.000000  2187.000000    2187.000000
# mean           0.144327     0.179097     0.513346   121.438764  199452.427984
# std            0.305159     0.147594     0.257360    29.390177   73237.552465
# min            0.000000     0.000000     0.000000     0.000000    8500.000000
# 25%            0.000000     0.092400     0.308500    98.968000  158169.500000
# 50%            0.000013     0.121000     0.517000   121.876000  196364.000000
# 75%            0.015400     0.215000     0.722500   139.933000  234373.000000
# max            1.000000     0.979000     1.000000   220.099000  998000.000000
#
#        time_signature
# count     2187.000000
# mean         3.933699
# std          0.390525
# min          0.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          5.000000

# %%
metric = r2_score
std = StandardScaler() 
nrm = MinMaxScaler()
# Out:
#    danceability  energy  key  loudness  mode  instrumentalness  liveness  \
# 0         0.731   0.626   11    -6.919     1          0.000000    0.1830
# 1         0.907   0.633    2    -5.145     1          0.000003    0.1060
# 2         0.574   0.629    2    -8.815     0          0.000000    0.2710
# 3         0.398   0.717    0    -5.253     1          0.000000    0.0850
# 4         0.593   0.500    1    -8.532     1          0.000012    0.0837
#
#    valence    tempo     views
# 0    0.862   82.488  24500000
# 1    0.395  145.914     15000
# 2    0.786  153.119  12000000
# 3    0.487  117.296    245100
# 4    0.465  117.996   7900000

# %%
data = df.loc[:,['danceability','energy','key','loudness','mode','instrumentalness','liveness','valence','tempo','views']]
targets = data['views'].apply(np.digitize,bins=[0,1e+5,1e+6])
data = data.loc[:,['danceability','energy','key','loudness','mode','instrumentalness','liveness','valence','tempo']]

# %%
regularized = nrm.fit_transform(data)
X, y = regularized, targets

# %%
def evaluate_model(model,X,y):
    scoring = ['precision_macro','recall_macro','accuracy']
    scores = cross_validate(model,X,y,scoring=scoring)
    mean_precision = scores['test_precision_macro'].mean()
    mean_recall = scores['test_recall_macro'].mean()
    mean_accuracy = scores['test_accuracy'].mean()
    return mean_precision,mean_recall,mean_accuracy

# %%
models = [
    ("Decision Tree",tree.DecisionTreeClassifier()),
    ("SVC",svm.SVC()),
    ("Logistic Regression",linear_model.LogisticRegression()),
    ("Complement Naive Bayes",naive_bayes.ComplementNB())
]
print("Model\tPrecision\tRecall\tAccuracy")
for name, model in models:
    scores = evaluate_model(model,X,y)
    print(f"{name}\t{scores[0]}\t{scores[1]}\t{scores[2]}")
# Out:
# Model	Precision	Recall	Accuracy
# Decision Tree	0.3189938194747983	0.31961510136295745	0.32557704565165146
# SVC	0.382055712592797	0.34481110935294174	0.40100832784761187
# Logistic Regression	0.3185794112340211	0.33075396478699287	0.38728775482482264
# Complement Naive Bayes	0.34785882323756245	0.34690398453183674	0.35666906993511177
# c:\users\georg\documents\msc-projcet\venv\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
baseline = DummyClassifier()
evaluate_model(baseline,X,y)
# Out:
# c:\users\georg\documents\msc-projcet\venv\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\georg\documents\msc-projcet\venv\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\georg\documents\msc-projcet\venv\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\georg\documents\msc-projcet\venv\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\georg\documents\msc-projcet\venv\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.13305922141068377, 0.3333333333333333, 0.3991776642320512)
